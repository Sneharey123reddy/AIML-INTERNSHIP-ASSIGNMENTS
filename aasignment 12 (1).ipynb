# %%
'''
Assignment (10/03/2026)

Assignment Name : Spam Classifier Thinking
Description : Design a spam detection system: features, data needed, possible mistakes.
'''

# %%
Assignment Name: Spam Classifier Thinking
#Problem Explanation
Design a system to detect whether a message is Spam or Not Spam.
#1. Features (Input Data)
Presence of keywords: “win”, “free”, “offer”
Number of links in message
Message length
Use of capital letters
Sender information
# 2. Data Needed
Collection of emails/SMS labeled as:
Spam
Not Spam
Large dataset improves accuracy
Text data for training (NLP based)
# 3. How It Works (ML Idea)
Convert text → numbers (using techniques like Bag of Words / TF-IDF)
Train model (Naive Bayes / Logistic Regression)
Predict:
Spam
Not Spam
# 4. Possible Mistakes
False Positive
Important message marked as spam
False Negative
Spam message marked as normal
New types of spam
Model may fail on unseen patterns
# Conclusion
Spam detection improves email safety
Requires continuous learning and updating
Widely used in real-world applications
