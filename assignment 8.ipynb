# %%
'''
*Assignment (02/03/2026)*

*Assignment Name* : ML Idea Generator
*Description* : Suggest ML problems in college, healthcare, shopping and describe input → output.
'''

# %%
Assignment Name: ML Idea Generator

Suggest Machine Learning problems in different domains and describe their input → output.
 1. College Domain – Student Performance Prediction
Problem: Predict whether a student will pass or fail
Input: Attendance, internal marks, study hours
Output: Pass / Fail (or predicted score)
✅ 2. Healthcare Domain – Disease Prediction
Problem: Predict risk of diseases (e.g., diabetes)
Input: Age, weight, blood pressure, sugar levels
Output: Disease risk (Yes/No or probability)
✅ 3. Shopping Domain – Product Recommendation System
Problem: Recommend products to users
Input: User browsing history, purchases, ratings
Output: List of recommended products
4. College Domain – Attendance Monitoring (Face Recognition)
Problem: Automatically mark attendance
Input: Student face images from camera
Output: Attendance record (Present/Absent)
5. Healthcare Domain – Appointment Prediction
Problem: Predict if a patient will miss an appointment
Input: Past visit history, time, patient behavior
Output: Show / No-show prediction
6. Shopping Domain – Price Prediction
Problem: Predict product price
Input: Product features, brand, category, demand
Output: Estimated price
7. College Domain – Course Recommendation System
Problem: Suggest courses to students
Input: Interests, previous marks, skills
Output: Recommended courses
8. Healthcare Domain – Medical Image Analysis
Problem: Detect disease from X-rays or scans
Input: Medical images
Output: Disease detected / Normal
