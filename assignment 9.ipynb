# %%
'''
*Assignment (03/03/2026)*

*Assignment Name* : Build Your First Dataset
*Description* : Create a dataset (e.g., study hours vs marks), identify features & labels, predict relationship.
'''

# %%
'''
Assignment Name: Build Your First Datasets
Create a simple dataset, identify features and labels, and understand the relationship between them.
'''
Sample Dataset (Study Hours vs Marks)
StudyHours   Marks
1             35
2             40
3             50
4             55
5             65
6             70
7             75
8             85
9             90
10            95
Features & Labels
Feature (Input): Study Hours
Label (Output): Marks
Understanding the Relationship
The data shows a positive relationship:
As study hours increase, marks also increase.
This is a linear relationship (approximately a straight line).
# Prediction Idea
We can predict marks using a simple linear equation:
Where:
x = Study Hours
y = Marks
m = slope (rate of increase)
c = constant
Example:
If a student studies 6 hours, predicted marks ≈ 70
Conclusion
More study hours generally lead to higher marks
This dataset can be used to train a Linear Regression model
Helps in predicting student performance
