# %%
'''
Task:
shopping cart:

create shopping cart using list:

add items, remove one item, print total items
'''

# %%
# Create an empty shopping cart
cart = []

# Function to add item
def add_item(item):
    cart.append(item)
    print(f"{item} added to cart.")

# Function to remove item
def remove_item(item):
    if item in cart:
        cart.remove(item)
        print(f"{item} removed from cart.")
    else:
        print(f"{item} not found in cart.")

# Function to print total items
def total_items():
    print("Total items in cart:", len(cart))
    print("Cart items:", cart)

# Example usage
add_item("Apple")
add_item("Banana")
add_item("Milk")

remove_item("Banana")

total_items()
# Out:
# Apple added to cart.
# Banana added to cart.
# Milk added to cart.
# Banana removed from cart.
# Total items in cart: 2
# Cart items: ['Apple', 'Milk']
