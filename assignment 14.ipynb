# %%
'''
*Assignment (12/03/2026)*

*Assignment Name* : Decision Tree on Paper
*Description* : Draw a decision tree predicting whether you should play outside.
'''

# %%
Create a Decision Tree to decide whether to play outside or not based on conditions like weather.
✅ Conditions Used
Weather (Sunny / Rainy / Cloudy)
Temperature (Hot / Mild / Cool)
Humidity (High / Normal)
✅ Decision Tree (Text Form)

Weather
               /    |     \
           Sunny  Rainy   Cloudy
            |       |        |
        Humidity   No     Yes
         /   \
      High  Normal
       |      |
      No     Yes
✅ Explanation
If Weather = Rainy → ❌ Do NOT play
If Weather = Cloudy → ✅ Play
If Weather = Sunny:
Humidity High → ❌ Do NOT play
Humidity Normal → ✅ Play
✅ Conclusion
Decision Trees help in making decisions step by step
Easy to understand and visualize
Used in many ML classification problems
