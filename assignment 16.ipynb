# %%
'''
Assignment (19/03/2026)
Assignment Name: Mini Project Proposal
Description:
Submit a 1-page proposal including the problem statement, dataset, algorithm, and expected output.
'''

# %%
Title: Customer Segmentation using Machine Learning
Problem Statement:
Businesses need to understand customer behavior to improve marketing strategies.
Dataset:
Mall Customers dataset (contains age, income, spending score)
Algorithm:
K-Means Clustering
Steps:
Data preprocessing
Feature selection
Apply K-Means
Visualize clusters
Expected Output:
Customer groups
Insights for marketing (target high-value customers)
