# %%
'''
📘 Assignment (21/03/2026)
Assignment Name: Build a Text Cleaner
Description:
Write code to remove punctuation, convert text to lowercase, remove stopwords, and test it.
'''

# %%
import re
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')

stop_words = set(stopwords.words('english'))

def clean_text(text):
    # Lowercase
    text = text.lower()
    
    # Remove punctuation
    text = re.sub(r'[^\w\s]', '', text)
    
    # Remove numbers
    text = re.sub(r'\d+', '', text)
    
    # Remove extra spaces
    text = re.sub(r'\s+', ' ', text).strip()
    
    # Remove stopwords
    words = text.split()
    words = [word for word in words if word not in stop_words]
    
    return " ".join(words)

# Test
sample = "OMG!!! This is sooo GOOD 😍!!!"
print(clean_text(sample))
# Out:
# omg sooo good
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/61b289ec-11b9-4a28-ba8b-
# [nltk_data]     de5051ae913c/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
